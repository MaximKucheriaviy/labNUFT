# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
data = pd.read_excel('source.xlsm')
data.info
# Out:
# <bound method DataFrame.info of     First name  Last name                 country   car make   car model year
# 0     Karlotte   Dilgarno                 Tunisia      Suzuki            2004
# 1       Jelene    Sayburn                   China        Jeep            2008
# 2       Linell     Runham  Bosnia and Herzegovina       Isuzu            2000
# 3       Hilary  Braidwood                   China        Ford            2004
# 4      Mariele   Gorringe                  Russia       Acura            1990
# ..         ...        ...                     ...         ...             ...
# 995       Kaja     Pasque                   Ghana  Volkswagen            2006
# 996     Fabian   Playhill                    Togo  Mitsubishi            2006
# 997    Valerye   Ciccotti                Slovenia         BMW            2008
# 998      Ginni     Pattie                   China  Mitsubishi            2009
# 999     Helena       Ubee                  Sweden       Dodge            1997
#
# ...

# %%
car_model_data = data.groupby(["car make ", "car model year"]).count()
car_model_data = car_model_data.rename(columns={"country":"count"})
sns.relplot(data=car_model_data, x="car model year", y="car make ", height=15, size="count", sizes=(50, 500))
plt.grid(True)
plt.gca().xaxis.set_major_locator(MultipleLocator(2))

# %%
year_model_data = data.groupby(["country", "car model year"]).count()
year_model_data = year_model_data.rename(columns={"car make ":"count"})
sns.relplot(data=year_model_data, x="car model year", y="country", aspect=0.5, height=25, size="count", sizes=(50, 300))
plt.grid(True)
plt.xticks(rotation=90)
plt.gca().xaxis.set_major_locator(MultipleLocator(2))

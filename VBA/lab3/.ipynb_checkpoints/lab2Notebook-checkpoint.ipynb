# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_excel('source.xlsm')
data.info
data.shape()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   First name      1000 non-null   object
#  1   Last name       1000 non-null   object
#  2   country         1000 non-null   object
#  3   car make        1000 non-null   object
#  4   car model year  1000 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
data.groupby('car make').count()
# Out:
#                 First name  Last name  country  car make
# car model year
# 1958                     2          2        2          2
# 1960                     1          1        1          1
# 1961                     2          2        2          2
# 1963                     1          1        1          1
# 1964                     1          1        1          1
# 1965                     2          2        2          2
# 1966                     2          2        2          2
# 1967                     4          4        4          4
# 1968                     1          1        1          1
# 1969                     2          2        2          2
# 1970                     3          3        3          3
# 1971                     2          2        2          2
# 1972                     3          3        3          3
# 1973                     2          2        2          2
# 1974                     1          1        1          1
# ...
